# %%
import time
import pandas as pd
from serpapi import GoogleSearch
from newspaper import Article
import openai
import os
from dotenv import load_dotenv


load_dotenv()
openai_api_key = os.getenv("OPENAI_KEY")
openai.api_key = openai_api_key

# %%
params = {
    "api_key": os.getenv("SERP_KEY"),
    "q": "business & politics in us",
    "engine": "bing_news",
    "first": 1,
    "count": 10,
    "qft": 'interval="9"',
}

search = GoogleSearch(params)
results = search.get_dict()

bing_news_results = []

page_limit = 5
page_count = 0

while "error" not in results and page_count < page_limit:
    bing_news_results.extend(results.get("organic_results", []))
    params["first"] += params["count"]
    page_count += 1
    search = GoogleSearch(params)
    results = search.get_dict()

df_bing_news_results = pd.DataFrame(bing_news_results)

# %%
urls = [result.get("link") for result in bing_news_results if "link" in result]

def scrape_article(url):
    article = Article(url)
    try:
        article.download()
        article.parse()
        return article.text
    except Exception as e:
        print(f"Failed to scrape {url}: {e}")
        return None

for url in urls:
    content = scrape_article(url)
    if content:
        df_bing_news_results.loc[df_bing_news_results["link"] == url, "content"] = (content)
    time.sleep(1)

df_bing_news_results.dropna(how="any", inplace=True)
# Out:
# Failed to scrape https://www.reuters.com/markets/us/us-political-churn-muddies-corporate-horizon-mike-dolan-2024-07-24/: Article `download()` failed with Status code 401 for url None on URL https://www.reuters.com/markets/us/us-political-churn-muddies-corporate-horizon-mike-dolan-2024-07-24/
# Failed to scrape https://www.realclearpolitics.com/articles/2024/07/23/the_most_important_42_miles_in_american_politics_151314.html: Article `download()` failed with Status code 403 for url None on URL https://www.realclearpolitics.com/articles/2024/07/23/the_most_important_42_miles_in_american_politics_151314.html
# /opt/homebrew/lib/python3.12/site-packages/dateutil/parser/_parser.py:1207: UnknownTimezoneWarning: tzname PST identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   warnings.warn("tzname {tzname} identified but not understood.  "
# /opt/homebrew/lib/python3.12/site-packages/dateutil/parser/_parser.py:1207: UnknownTimezoneWarning: tzname PST identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   warnings.warn("tzname {tzname} identified but not understood.  "
# /opt/homebrew/lib/python3.12/site-packages/dateutil/parser/_parser.py:1207: UnknownTimezoneWarning: tzname PST identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   warnings.warn("tzname {tzname} identified but not understood.  "

# %%
df_bing_news_results
# Out:
#                                                 title  \
# 6   Milwaukee RNC an 'unprecedented' moment combin...
# 11  Employees Sue American Airlines Over “Socio-Po...
# 15  The small business community’s crucial role in...
# 17  Speak up or keep quiet: When politics and busi...
# 21  MTG and Lauren Boebert are incendiary lawmaker...
# 23  How does U.S. political violence affect global...
# 24  Investors React to Election Upheaval, Reassess...
# 25  The Ohio Steel Town That Shaped J.D. Vance’s L...
# 30  Investors React to Election Upheaval, Reassess...
# 32  The Ohio Steel Town That Shaped J.D. Vance’s L...
# 37  Rod Miller: Wyoming’s Shameful New Political C...
# 38  US extreme political elites' plot to crush Chi...
# 40  The return of a US-China trade war? Q&A with p...
# 42  What three statehouse primaries tell us about ...
# 43  Investors React to Election Upheaval, Reassess...
# 46  The world's most accurate economist shares his...
# 49     It’s Business as Usual for Business (For Now)…
#
#                                                  link  \
# 6   https://www.usatoday.com/story/news/politics/2...
# 11  https://www.motherjones.com/politics/2024/07/a...
# 15  https://www.dailyherald.com/20240721/business/...
# 17  https://www.businessobserverfl.com/news/2024/j...
# 21  https://www.businessinsider.com/mtg-boebert-he...
# 23  https://www.marketplace.org/2024/07/16/us-poli...
# 24  https://www.nytimes.com/2024/07/22/us/politics...
# 25  https://www.nytimes.com/2024/07/16/us/jd-vance...
# 30  https://www.nytimes.com/2024/07/22/us/politics...
# 32  https://www.nytimes.com/2024/07/16/us/jd-vance...
# 37  https://cowboystatedaily.com/2024/07/21/rod-mi...
# 46  To be fair to everyone else, many economic ind...
# 49  Jonny McCormick is a Senior Director at Lancia...

# %%
def sentiment_analysis(text):
    prompt = (
        'For the following industry sectors, provide the sentiment (good or bad). '
        'If it is not related to the sector, mention the sentiment as (None): '
        '1. Technology industry 2. Business industry 3. Sports industry '
        '4. Healthcare industry 5. Transportation industry 6. Film industry 7. Fashion industry. '
        'If the context is there the response should look like (Good - statement) otherwise it has to just be (None)\n\n'
        f'"{text}"'
    )

    response = openai.chat.completions.create(
        model="gpt-4",
        messages=[
            {"role": "system", "content": "You are a helpful assistant."},
            {"role": "user", "content": prompt},
        ],
        max_tokens=150,
        n=1,
        stop=None,
        temperature=0.7
    )

    response_text = response.choices[0].message.content
    
    return response_text

# %%
def sector_sentiment_split(response_text):
    
    sentiments = {}
    sectors = [
        "Technology industry", "Business industry", "Sports industry",
        "Healthcare industry", "Transportation industry", "Film industry", "Fashion industry"
    ]

    for sector in sectors:
        if sector in response_text:
            start_index = response_text.find(sector) + len(sector) + 1
            end_index = response_text.find('\n', start_index)
            if end_index == -1:
                end_index = len(response_text)
            sentiment_and_reason = response_text[start_index:end_index].strip()
            if sentiment_and_reason == "None":  # Check if the string is not empty
                sentiments[sector] = None
            else:
                sentiments[sector] = sentiment_and_reason

    for sector, sentiment_and_reason in sentiments.items():
        globals()[sector] = sentiment_and_reason

    return sentiments

# %%
# response_text = pd.DataFrame()
for idx, row in df_bing_news_results.iterrows():
    if pd.notna(row.get("content")):
        response_text = sentiment_analysis(row["content"])
        sentiments = sector_sentiment_split(response_text)
        for sector, sentiment in sentiments.items():
            df_bing_news_results.at[idx, sector] = sentiment


df_bing_news_results.fillna(value="None", inplace=True)

# %%
df_bing_news_results[[
    "Technology industry", "Business industry", "Sports industry",
    "Healthcare industry", "Transportation industry", "Film industry", "Fashion industry"
]]
# Out:
#                                   Technology industry  \
# 6                                                None
# 11                                               None
# 15                                               None
# 17                                             - None
# 21                                               None
# 23                                               None
# 24  - Bad (Taiwan’s main stock index dropped sharp...
# 25                                               None
# 30  - (Bad - Taiwan’s main stock index dropped sha...
# 32                                               None
# 37                                               None
# 38                                               None
# 40  (Bad - Global stock markets tumbled the day af...
# 42                                               None
# 43  - Bad (Taiwan’s main stock index dropped sharp...
# 46                                             - None
# 49                                               None
#
#                                     Business industry Sports industry  \
# 6                                                None            None
# 11                                               None            None
# 15                                                               None
# 17  - Good (Business owners are expressing their p...          - None
# 21                                               None            None
# 23                                                               None
# 24  - Mixed (Investors around the world are trying...            None
# 25                                               None            None
# 30                                           - (None)        - (None)
# 32                                               None            None
# 37                                               None            None
# 38                                               None            None
# 40             (Bad - The threats of imposing tariffs            None
# 42                                               None            None
# 43                                             - None          - None
# 46  - Bad (A sore part of the US economy is househ...          - None
# 49  The text mentions potential disruptions and un...            None
#
#    Healthcare industry Transportation industry Film industry Fashion industry
# 6                 None                    None          None             None
# 11                None                    None          None             None
# 15                None                    None          None             None
# 17              - None                  - None        - None           - None
# 21                None                    None          None             None
# 23                None                    None          None             None
# 24                None                    None          None             None
# 25                None                    None          None             None
# 30            - (None)                - (None)      - (None)         - (None)
# 32                None                    None          None             None
# 37                None                    None          None             None
# 38                None                    None          None             None
# 40                None                    None          None             None
# 42                None                    None          None             None
# 43              - None                  - None        - None           - None
# 46              - None                  - None        - None           - None
# 49                None                    None          None             None
